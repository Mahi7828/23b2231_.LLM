# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.1

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent=[  'the book on the table',
     'Bring the glass of milk ',
     'He goes to the market everyday',
    'Meena claims the property',
     'is she fine?',
     'lets go to the zoo',
     'you cook really amazing']

# %%
sent
# Out:
# ['the book on the table',
#  'Bring the glass of milk ',
#  'He goes to the market everyday',
#  'Meena claims the property',
#  'is she fine?',
#  'lets go to the zoo',
#  'you cook really amazing']

# %%
voc_size = 400

# %%
onehot_repr=[one_hot(words,voc_size)for words in sent]

# %%
print(onehot_repr)
# Out:
# [[72, 117, 197, 72, 176], [179, 72, 247, 45, 176], [248, 21, 351, 72, 301, 298], [57, 108, 72, 8], [162, 109, 359], [334, 34, 351, 72, 95], [334, 192, 356, 189]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 10
embedded_docs=pad_sequences(onehot_repr, padding = 'pre',maxlen = sent_length)
print(embedded_docs)
# Out:
# [[  0   0   0   0   0  72 117 197  72 176]
#  [  0   0   0   0   0 179  72 247  45 176]
#  [  0   0   0   0 248  21 351  72 301 298]
#  [  0   0   0   0   0   0  57 108  72   8]
#  [  0   0   0   0   0   0   0 162 109 359]
#  [  0   0   0   0   0 334  34 351  72  95]
#  [  0   0   0   0   0   0 334 192 356 189]]

# %%
model = Sequential()
model.add(Embedding(voc_size , 7 , input_length=sent_length))
model.compile('adam' , 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 10, 7)             2800
#
# =================================================================
# Total params: 2800 (10.94 KB)
# Trainable params: 2800 (10.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
embedded_docs[0]
# Out:
# array([  0,   0,   0,   0,   0,  72, 117, 197,  72, 176])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 58ms/step
# array([[-0.01562705, -0.01612213,  0.01654091,  0.04113818,  0.04047674,
#         -0.04938601,  0.0103564 ],
#        [-0.01562705, -0.01612213,  0.01654091,  0.04113818,  0.04047674,
#         -0.04938601,  0.0103564 ],
#        [-0.01562705, -0.01612213,  0.01654091,  0.04113818,  0.04047674,
#         -0.04938601,  0.0103564 ],
#        [-0.01562705, -0.01612213,  0.01654091,  0.04113818,  0.04047674,
#         -0.04938601,  0.0103564 ],
#        [-0.01562705, -0.01612213,  0.01654091,  0.04113818,  0.04047674,
#         -0.04938601,  0.0103564 ],
#        [ 0.00801184, -0.02034267, -0.01357306,  0.0125595 , -0.03829545,
#         -0.03803247,  0.01266626],
#        [-0.02565721,  0.04787589,  0.01941374,  0.04345896, -0.04277903,
#         -0.02214551, -0.01583755],
#        [-0.0350632 ,  0.00521071, -0.04558743,  0.00764791, -0.01328193,
#          0.00767148, -0.04222948],
#        [ 0.00801184, -0.02034267, -0.01357306,  0.0125595 , -0.03829545,
#         -0.03803247,  0.01266626],
#        [ 0.04355286, -0.00712381,  0.0028468 , -0.04790256,  0.04525678,
#         -0.01924378,  0.00395108]], dtype=float32)

# %%
print(model.predict(embedded_docs))
# Out:
# 1/1 [==============================] - 0s 63ms/step
# [[[-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [ 0.00801184 -0.02034267 -0.01357306  0.0125595  -0.03829545
#    -0.03803247  0.01266626]
#   [-0.02565721  0.04787589  0.01941374  0.04345896 -0.04277903
#    -0.02214551 -0.01583755]
#   [-0.0350632   0.00521071 -0.04558743  0.00764791 -0.01328193
#     0.00767148 -0.04222948]
#   [ 0.00801184 -0.02034267 -0.01357306  0.0125595  -0.03829545
#    -0.03803247  0.01266626]
#   [ 0.04355286 -0.00712381  0.0028468  -0.04790256  0.04525678
#    -0.01924378  0.00395108]]
#
#  [[-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [ 0.04219818 -0.04560382  0.03501128 -0.02957972 -0.04293094
#    -0.01825362  0.02465625]
#   [ 0.00801184 -0.02034267 -0.01357306  0.0125595  -0.03829545
#    -0.03803247  0.01266626]
#   [ 0.03818886  0.02660623  0.00762687  0.03406582 -0.0345301
#     0.0111794   0.02971223]
#   [-0.01598278 -0.00202843 -0.03258107  0.01670655 -0.01868937
#    -0.00314332  0.01186555]
#   [ 0.04355286 -0.00712381  0.0028468  -0.04790256  0.04525678
#    -0.01924378  0.00395108]]
#
#  [[-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [ 0.02900397 -0.03087971  0.0134452   0.03239787 -0.00854647
#     0.0163017  -0.00683076]
#   [-0.04317837  0.02732649 -0.02516486 -0.00238914  0.03381384
#    -0.03831293  0.033521  ]
#   [ 0.0039714   0.02625087 -0.03796436  0.01831983  0.01154602
#     0.00671235 -0.04122468]
#   [ 0.00801184 -0.02034267 -0.01357306  0.0125595  -0.03829545
#    -0.03803247  0.01266626]
#   [ 0.02672799 -0.03076063 -0.02088067 -0.02819868 -0.03640462
#     0.00922054 -0.02104931]
#   [-0.01968524 -0.01374853 -0.03600652 -0.02719959  0.0038435
#    -0.00807092 -0.0006902 ]]
#
#  [[-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [ 0.03146836  0.00123724 -0.00773881 -0.00864263 -0.00303952
#    -0.01397481  0.01021941]
#   [ 0.02298922 -0.00941052  0.00759764 -0.04138548  0.01313107
#     0.00586542 -0.04951593]
#   [ 0.00801184 -0.02034267 -0.01357306  0.0125595  -0.03829545
#    -0.03803247  0.01266626]
#   [-0.0135205   0.04073478  0.02995776  0.02513642  0.02322641
#     0.02884612  0.01776792]]
#
#  [[-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.0436716   0.03108069 -0.01447377  0.02588042  0.0484331
#     0.02953676  0.03154105]
#   [-0.03321028 -0.01671611  0.04949108 -0.01963413 -0.04061078
#     0.03862845 -0.03451356]
#   [ 0.01475935  0.00180168 -0.00469099 -0.01114978  0.0187291
#    -0.00658984  0.00139225]]
#
#  [[-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.02173756  0.03999046  0.01653479 -0.04695563  0.04626428
#    -0.03403194 -0.01147978]
#   [ 0.04332132  0.02305862 -0.01093411  0.03535143  0.01828966
#    -0.00296425 -0.01993752]
#   [ 0.0039714   0.02625087 -0.03796436  0.01831983  0.01154602
#     0.00671235 -0.04122468]
#   [ 0.00801184 -0.02034267 -0.01357306  0.0125595  -0.03829545
#    -0.03803247  0.01266626]
#   [-0.04527615 -0.04240591  0.01077622  0.04442071  0.03631513
#     0.03777478  0.00586132]]
#
#  [[-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.01562705 -0.01612213  0.01654091  0.04113818  0.04047674
#    -0.04938601  0.0103564 ]
#   [-0.02173756  0.03999046  0.01653479 -0.04695563  0.04626428
#    -0.03403194 -0.01147978]
#   [ 0.00631313 -0.0472615  -0.01648592  0.00568949  0.01844425
#    -0.00625636 -0.00794221]
#   [-0.03732171 -0.00078558 -0.04086735 -0.04946008  0.01335463
#    -0.03699653  0.01371738]
#   [ 0.0183573  -0.0100056   0.04779711 -0.00186632 -0.04728357
#    -0.02871761  0.00804178]]]

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting click (from nltk)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mahim\.conda\envs\conda_ten\lib\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\mahim\.conda\envs\conda_ten\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\mahim\.conda\envs\conda_ten\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: joblib, click, nltk
# Successfully installed click-8.1.7 joblib-1.4.2 nltk-3.8.1
